# %% [markdown]
# # Recommendation Based on Patient's Complaint
#
# Sequence to sequence task

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('https://drive.google.com/uc?id=1PDEP8PtLM1BrqYyyCaklFsmTmXNMGiXF')

# %% [markdown]
# ## Exploratory Data Analysis
