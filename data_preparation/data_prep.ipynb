# %% [markdown]
# # Prepare Data Needed

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Classification Sample

# %%
df = pd.read_csv('https://drive.google.com/uc?id=1_zcMlbdDNZ93FRRS-pmnD5j10mfUu3ke', encoding='latin-1')
save_data = df.copy().head(2000)

save_data.to_csv('HealthCare Data 2000.csv', index=False)

# %% [markdown]
# ## Sequence to Sequence Data Transformation
